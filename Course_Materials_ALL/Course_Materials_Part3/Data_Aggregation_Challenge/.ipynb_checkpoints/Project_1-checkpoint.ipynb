# %%
import pandas as pd
import numpy as np

# %%
summer = pd.read_csv("summer.csv")
sum1996 = pd.read_csv("wik_1996.csv")
sum1976 = pd.read_csv("wik_1976.csv")

# %% [markdown]
# Inspecting The All the DataSets!

# %% [markdown]
# # Inspecting Summer Dataset

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
#checking for null(s)
summer[summer.isna().any(axis = 1)]
# Out:
#        Year    City          Sport           Discipline          Athlete  \
# 29603  2012  London      Athletics            Athletics          Pending
# 31072  2012  London  Weightlifting        Weightlifting          Pending
# 31091  2012  London  Weightlifting        Weightlifting          Pending
# 31110  2012  London      Wrestling  Wrestling Freestyle  KUDUKHOV, Besik
#
#       Country Gender     Event   Medal
# 29603     NaN  Women     1500M    Gold
# 31072     NaN  Women      63KG    Gold
# 31091     NaN    Men      94KG  Silver
# 31110     NaN    Men  Wf 60 KG  Silver

# %%
summer.dropna(inplace = True)

# %% [markdown]
# # Inspecting wik_1996 Dataset

# %%
sum1976
# Out:
#                 Rank                        NOC  Gold  Silver  Bronze  Total
# 0                  1         Soviet Union (URS)    49      41      35    125
# 1                  2         East Germany (GDR)    40      25      25     90
# 2                  3        United States (USA)    34      35      25     94
# 3                  4         West Germany (FRG)    10      12      17     39
# 4                  5                Japan (JPN)     9       6      10     25
# 5                  6               Poland (POL)     7       6      13     26
# 6                  7             Bulgaria (BUL)     6       9       7     22
# 7                  8                 Cuba (CUB)     6       4       3     13
# 8                  9              Romania (ROU)     4       9      14     27
# 9                 10              Hungary (HUN)     4       5      13     22
# 10                11              Finland (FIN)     4       2       0      6
# ...

# %%
sum1976.NOC.str.split("(", expand = True).iloc[:, 1].str.replace(")", "").str.replace("*","")
# Out:
# 0         URS
# 1         GDR
# 2         USA
# 3         FRG
# 4         JPN
# 5         POL
# 6         BUL
# 7         CUB
# 8         ROU
# 9         HUN
# 10        FIN
# 11        SWE
# 12        GBR
# 13        ITA
# 14        FRA
# 15        YUG
# 16        TCH
# 17        NZL
# 18        KOR
# 19        SUI
# 20        JAM
# 21        PRK
# 22        NOR
# 23        DEN
# 24        MEX
# 25        TRI
# 26        CAN
# 27        BEL
# 28        NED
# 29        POR
# 30        ESP
# 31        AUS
# 32        IRI
# 33        MGL
# 34        VEN
# 35        BRA
# 36        AUT
# 37        BER
# 38        PAK
# 39        PUR
# 40        THA
# 41    41 NOCs
# Name: 1, dtype: object

# %%
#Create a new column of country by spliting the NOC
sum1976["Country"] = sum1976.NOC.str.split("(", expand = True).iloc[:, 1].str.replace(")", "").str.replace("*","")

# %%
sum1976
# Out:
#                 Rank                        NOC  Gold  Silver  Bronze  Total  \
# 0                  1         Soviet Union (URS)    49      41      35    125
# 1                  2         East Germany (GDR)    40      25      25     90
# 2                  3        United States (USA)    34      35      25     94
# 3                  4         West Germany (FRG)    10      12      17     39
# 4                  5                Japan (JPN)     9       6      10     25
# 5                  6               Poland (POL)     7       6      13     26
# 6                  7             Bulgaria (BUL)     6       9       7     22
# 7                  8                 Cuba (CUB)     6       4       3     13
# 8                  9              Romania (ROU)     4       9      14     27
# 9                 10              Hungary (HUN)     4       5      13     22
# 10                11              Finland (FIN)     4       2       0      6
# ...

# %%
sum1976.drop(columns = ["Rank", "NOC", "Total"], inplace= True)

# %%
sum1976.set_index("Country", inplace= True)

# %%
sum1976
# Out:
#          Gold  Silver  Bronze
# Country
# URS        49      41      35
# GDR        40      25      25
# USA        34      35      25
# FRG        10      12      17
# JPN         9       6      10
# POL         7       6      13
# BUL         6       9       7
# CUB         6       4       3
# ROU         4       9      14
# HUN         4       5      13
# FIN         4       2       0
# SWE         4       1       0
# GBR         3       5       5
# ITA         2       7       4
# FRA         2       3       4
# YUG         2       3       3
# TCH         2       2       4
# NZL         2       1       1
# KOR         1       1       4
# SUI         1       1       2
# JAM         1       1       0
# PRK         1       1       0
# NOR         1       1       0
# DEN         1       0       2
# MEX         1       0       1
# TRI         1       0       0
# CAN         0       5       6
# BEL         0       3       3
# NED         0       2       3
# ...

# %% [markdown]
# # Inspecting wik_1996 Dataset

# %%
sum1996
# Out:
#                    Rank                Nation  Gold  Silver  Bronze  Total
# 0                     1  United States (USA)*    44      32      25    101
# 1                     2          Russia (RUS)    26      21      16     63
# 2                     3         Germany (GER)    20      18      27     65
# 3                     4           China (CHN)    16      22      12     50
# 4                     5          France (FRA)    15       7      15     37
# ..                  ...                   ...   ...     ...     ...    ...
# 75                   71      Mozambique (MOZ)     0       0       1      1
# 76                   71     Puerto Rico (PUR)     0       0       1      1
# 77                   71         Tunisia (TUN)     0       0       1      1
# 78                   71          Uganda (UGA)     0       0       1      1
# 79  Totals (79 nations)   Totals (79 nations)   271     273     298    842
#
# [80 rows x 6 columns]

# %%
sum1996["Country"] = sum1996.Nation.str.split("(",expand= True).iloc[:,1].str.replace(")", "").str.replace("*","")

# %%
sum1996
# Out:
#                    Rank                Nation  Gold  Silver  Bronze  Total  \
# 0                     1  United States (USA)*    44      32      25    101
# 1                     2          Russia (RUS)    26      21      16     63
# 2                     3         Germany (GER)    20      18      27     65
# 3                     4           China (CHN)    16      22      12     50
# 4                     5          France (FRA)    15       7      15     37
# ..                  ...                   ...   ...     ...     ...    ...
# 75                   71      Mozambique (MOZ)     0       0       1      1
# 76                   71     Puerto Rico (PUR)     0       0       1      1
# 77                   71         Tunisia (TUN)     0       0       1      1
# 78                   71          Uganda (UGA)     0       0       1      1
# 79  Totals (79 nations)   Totals (79 nations)   271     273     298    842
#
#        Country
# 0          USA
# 1          RUS
# 2          GER
# ...

# %%
sum1996 = sum1996.drop(columns = ["Rank", "Nation", "Total"]).set_index("Country")

# %%
sum1996
# Out:
#             Gold  Silver  Bronze
# Country
# USA           44      32      25
# RUS           26      21      16
# GER           20      18      27
# CHN           16      22      12
# FRA           15       7      15
# ...          ...     ...     ...
# MOZ            0       0       1
# PUR            0       0       1
# TUN            0       0       1
# UGA            0       0       1
# 79 nations   271     273     298
#
# [80 rows x 3 columns]

# %% [markdown]
# # Seperating Event Gender

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
#event contains the string "mixed"
summer.Event.str.lower().str.contains("mixed").sum()
# Out:
# 38

# %%
#event contains the string "pairs"
summer.Event.str.lower().str.contains("pairs").sum()
# Out:
# 12

# %%
summer.Sport.loc[summer.Sport == "Equestrian"]
# Out:
# 348      Equestrian
# 349      Equestrian
# 350      Equestrian
# 351      Equestrian
# 352      Equestrian
#             ...
# 30121    Equestrian
# 30122    Equestrian
# 30123    Equestrian
# 30124    Equestrian
# 30125    Equestrian
# Name: Sport, Length: 939, dtype: object

# %%
#Sport contains the string "equestrian"
summer.Sport.str.lower().str.contains("equestrian").sum()
# Out:
# 939

# %%
#All sailing event before 1988 were a mixed event
((summer.Sport.str.contains("Sailing")) & (summer.Year < 1988)).sum()
# Out:
# 755

# %%
summer["Event_Gender"] = summer.Gender

# %%
mask1 = summer.Event.str.lower().str.contains("mixed")
mask2 = summer.Event.str.lower().str.contains("pairs")
mask3 = summer.Sport.str.lower().str.contains("equestrian")
mask4 = ((summer.Sport.str.lower().str.contains("sailing")) & (summer.Year < 1988))

# %%
#Assign all the mixed Event with 'X'
summer.loc[mask1 | mask2 | mask3| mask4, "Event_Gender"] = "X"

# %% [markdown]
# Badminton also has mixed Event

# %%
bad_mixed = [21773, 21782, 21776,21785, 21770, 21779,23703,23712,23706, 23715,23709,23700,25720,25729,25723,25732,25726,
              25717,27727,27736, 27730,27739,27724,27733, 29784, 29785,29786,29787,29788,29789]

# %%
summer.loc[bad_mixed, "Event_Gender"] = "X"

# %% [markdown]
# # Counting Medals in Each Event

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.groupby(["Year", "Sport", "Discipline", "Event", "Event_Gender"]).Medal.count().unstack()
# Out:
# Event_Gender                                                   Men  Women   X
# Year Sport     Discipline          Event
# 1896 Aquatics  Swimming            100M Freestyle              2.0    NaN NaN
#                                    100M Freestyle For Sailors  3.0    NaN NaN
#                                    1200M Freestyle             3.0    NaN NaN
#                                    400M Freestyle              3.0    NaN NaN
#      Athletics Athletics           100M                        4.0    NaN NaN
# ...                                                            ...    ...  ..
# 2012 Wrestling Wrestling Freestyle Wg 60 KG                    4.0    NaN NaN
#                                    Wg 66 KG                    4.0    NaN NaN
#                                    Wg 74 KG                    4.0    NaN NaN
#                                    Wg 84 KG                    4.0    NaN NaN
# ...

# %%
summer["Event_Medal_Count"] = summer.groupby(["Year", "Sport", "Discipline", "Event", "Event_Gender"]).Medal.transform("count")

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.Event_Medal_Count.value_counts().sort_index()
# Out:
# Event_Medal_Count
# 1         5
# 2        54
# 3      9228
# 4      1684
# 5        50
#        ...
# 73       73
# 74       74
# 76       76
# 82       82
# 116     116
# Name: count, Length: 66, dtype: int64

# %% [markdown]
# # After couting Medal for each Event, assign if the event is a single or team event

# %%
summer["Team"] = pd.Series(np.where(summer.Event_Medal_Count > 5, "Yes", "No"))

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.Team.value_counts()
# Out:
# Team
# Yes    20140
# No     11021
# Name: count, dtype: int64

# %% [markdown]
# # Removing Duplicate from Team Events

# %%
summer.reset_index(inplace=True)

# %%
summer
# Out:
#        index  Year    City      Sport           Discipline  \
# 0          0  1896  Athens   Aquatics             Swimming
# 1          1  1896  Athens   Aquatics             Swimming
# 2          2  1896  Athens   Aquatics             Swimming
# 3          3  1896  Athens   Aquatics             Swimming
# 4          4  1896  Athens   Aquatics             Swimming
# ...      ...   ...     ...        ...                  ...
# 31156  31160  2012  London  Wrestling  Wrestling Freestyle
# 31157  31161  2012  London  Wrestling  Wrestling Freestyle
# 31158  31162  2012  London  Wrestling  Wrestling Freestyle
# 31159  31163  2012  London  Wrestling  Wrestling Freestyle
# 31160  31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# ...

# %%
singles = summer.loc[summer.Team == "No"].copy()
singles.shape
# Out:
# (11021, 13)

# %%
team = summer.loc[summer.Team == "Yes"].copy()
team.shape
# Out:
# (20140, 13)

# %%
team
# Out:
#        index  Year    City       Sport   Discipline               Athlete  \
# 84        84  1896  Athens  Gymnastics  Artistic G.        BÖCKER, Konrad
# 85        85  1896  Athens  Gymnastics  Artistic G.        FLATOW, Alfred
# 86        86  1896  Athens  Gymnastics  Artistic G.  FLATOW, Gustav Felix
# 87        87  1896  Athens  Gymnastics  Artistic G.         HILMAR, Georg
# 88        88  1896  Athens  Gymnastics  Artistic G.        HOFMANN, Fritz
# ...      ...   ...     ...         ...          ...                   ...
# 31041  31042  2012  London  Volleyball   Volleyball             OTOMO, Ai
# 31042  31043  2012  London  Volleyball   Volleyball         SAKODA, Saori
# 31043  31044  2012  London  Volleyball   Volleyball            SANO, Yuko
# 31044  31045  2012  London  Volleyball   Volleyball        SHINNABE, Risa
# 31045  31046  2012  London  Volleyball   Volleyball     TAKESHITA, Yoshie
#
#       Country Gender                 Event   Medal Event_Gender  \
# ...

# %%
team.drop_duplicates(subset = ["Year", "Sport", "Discipline", "Country", "Event", "Event_Gender", "Medal"], inplace = True)

# %%
team.shape
# Out:
# (3701, 13)

# %%
summer_new = pd.concat([singles, team])

# %%
summer_new.set_index("index", inplace= True)

# %%
summer_new
# Out:
#        Year    City       Sport  Discipline               Athlete Country  \
# index
# 0      1896  Athens    Aquatics    Swimming         HAJOS, Alfred     HUN
# 1      1896  Athens    Aquatics    Swimming      HERSCHMANN, Otto     AUT
# 2      1896  Athens    Aquatics    Swimming     DRIVAS, Dimitrios     GRE
# 3      1896  Athens    Aquatics    Swimming    MALOKINIS, Ioannis     GRE
# 4      1896  Athens    Aquatics    Swimming    CHASAPIS, Spiridon     GRE
# ...     ...     ...         ...         ...                   ...     ...
# 30988  2012  London  Volleyball  Volleyball  ALVES, Thiago Soares     BRA
# 31000  2012  London  Volleyball  Volleyball          BARI, Andrea     ITA
# 31012  2012  London  Volleyball  Volleyball      CAIXETA, Tandara     BRA
# 31024  2012  London  Volleyball  Volleyball    AKINRADEWO, Foluke     USA
# 31036  2012  London  Volleyball  Volleyball          ARAKI, Erika     JPN
#
#       Gender                       Event   Medal Event_Gender  \
# index
# ...

# %% [markdown]
# # Creating The Official Medal Table for all Editions

# %%
summer_new.groupby(["Year", "Country", "Medal"]).Medal.count().unstack(fill_value = 0)[["Gold", "Silver", "Bronze"]]
# Out:
# Medal         Gold  Silver  Bronze
# Year Country
# 1896 AUS         2       0       0
#      AUT         2       1       2
#      DEN         1       2       3
#      FRA         5       4       2
#      GBR         2       3       2
# ...            ...     ...     ...
# 2012 UGA         1       0       0
#      UKR         6       4       9
#      USA        46      28      32
#      UZB         1       0       2
#      VEN         1       0       0
#
# [1157 rows x 3 columns]

# %%
medal_table = summer_new.groupby(["Year", "Country", "Medal"]).Medal.count().unstack(fill_value = 0)[["Gold", "Silver", "Bronze"]]

# %% [markdown]
# # Comparing
