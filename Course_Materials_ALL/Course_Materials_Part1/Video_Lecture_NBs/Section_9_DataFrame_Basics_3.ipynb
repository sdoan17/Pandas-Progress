# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.age.sort_values()
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: age, Length: 891, dtype: float64

# %%
titanic.sort_values(by = "age", inplace= False) #sort the whole data frame by change the inplace to True
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 803         1       3    male  0.42      0      1   8.5167        C  NaN
# 755         1       2    male  0.67      1      1  14.5000        S  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 78          1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by = "age", ascending= False, inplace= False)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 630         1       1    male  80.0      0      0  30.0000        S    A
# 851         0       3    male  74.0      0      0   7.7750        S  NaN
# 493         0       1    male  71.0      0      0  49.5042        C  NaN
# 96          0       1    male  71.0      0      0  34.6542        C    A
# 116         0       3    male  70.5      0      0   7.7500        Q  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 863         0       3  female   NaN      8      2  69.5500        S  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by = ["pclass", "sex", "age"], ascending= True, inplace= True) #prioritize the first element

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 297         0       1  female   2.0      1      2  151.5500        S    C
# 435         1       1  female  14.0      1      2  120.0000        S    B
# 689         1       1  female  15.0      0      1  211.3375        S    B
# 329         1       1  female  16.0      0      1   57.9792        C    B
# 504         1       1  female  16.0      0      0   86.5000        S    B
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 837         0       3    male   NaN      0      0    8.0500        S  NaN
# 846         0       3    male   NaN      8      2   69.5500        S  NaN
# 859         0       3    male   NaN      0      0    7.2292        C  NaN
# 868         0       3    male   NaN      0      0    9.5000        S  NaN
# 878         0       3    male   NaN      0      0    7.8958        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by = ["pclass", "sex", "age"], ascending= [True, True,False], inplace= True) 
#pclass and sex are in ascending, age is in decending. Still prioritize the first element

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 275         1       1  female  63.0      1      0   77.9583        S    D
# 829         1       1  female  62.0      0      0   80.0000      NaN    B
# 366         1       1  female  60.0      1      0   75.2500        C    D
# 11          1       1  female  58.0      0      0   26.5500        S    C
# 195         1       1  female  58.0      0      0  146.5208        C    B
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 837         0       3    male   NaN      0      0    8.0500        S  NaN
# 846         0       3    male   NaN      8      2   69.5500        S  NaN
# 859         0       3    male   NaN      0      0    7.2292        C  NaN
# 868         0       3    male   NaN      0      0    9.5000        S  NaN
# 878         0       3    male   NaN      0      0    7.8958        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_index(ascending= True, inplace= True) #reset the dataframe by sort the index

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.sort_values(by = "age", ignore_index= True) 
# sort the dataframe and also reset the index accroding to dataframe
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           1       3    male  0.42      0      1   8.5167        C  NaN
# 1           1       2    male  0.67      1      1  14.5000        S  NaN
# 2           1       3  female  0.75      2      1  19.2583        C  NaN
# 3           1       3  female  0.75      2      1  19.2583        C  NaN
# 4           1       2    male  0.83      0      2  29.0000        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       3    male   NaN      0      0   7.2292        C  NaN
# 887         0       3  female   NaN      8      2  69.5500        S  NaN
# 888         0       3    male   NaN      0      0   9.5000        S  NaN
# 889         0       3    male   NaN      0      0   7.8958        S  NaN
# 890         0       3  female   NaN      1      2  23.4500        S  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# # Ranking DataFrames with rank()

# %%
sales = pd.Series([15,32,45,21,55,15,0], index = ["Mo", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"])

# %%
sales
# Out:
# Mo     15
# Tue    32
# Wed    45
# Thu    21
# Fri    55
# Sat    15
# Sun     0
# dtype: int64

# %%
sales.sort_values(ascending=False)
# Out:
# Fri    55
# Wed    45
# Tue    32
# Thu    21
# Mo     15
# Sat    15
# Sun     0
# dtype: int64

# %%
sales.rank().sort_values(ascending=False)
# Out:
# Fri    7.0
# Wed    6.0
# Tue    5.0
# Thu    4.0
# Mo     2.5
# Sat    2.5
# Sun    1.0
# dtype: float64

# %%
sales.rank(ascending=False).sort_values(ascending=True)
# Out:
# Fri    1.0
# Wed    2.0
# Tue    3.0
# Thu    4.0
# Mo     5.5
# Sat    5.5
# Sun    7.0
# dtype: float64

# %%
sales.rank(ascending=False, method = "min").sort_values(ascending=True)
# Out:
# Fri    1.0
# Wed    2.0
# Tue    3.0
# Thu    4.0
# Mo     5.0
# Sat    5.0
# Sun    7.0
# dtype: float64

# %%
sales.rank(ascending=False, method = "min", pct = True).sort_values(ascending=True)
# Out:
# Fri    0.142857
# Wed    0.285714
# Tue    0.428571
# Thu    0.571429
# Mo     0.714286
# Sat    0.714286
# Sun    1.000000
# dtype: float64

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.fare.rank(ascending= False)
# Out:
# 0      815.0
# 1      103.0
# 2      659.5
# 3      144.0
# 4      628.0
#        ...
# 886    484.5
# 887    237.5
# 888    345.5
# 889    237.5
# 890    768.5
# Name: fare, Length: 891, dtype: float64

# %%
titanic["fare_rank"] = titanic.fare.rank(ascending=False, method = "min")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
#
#    fare_rank
# 0      809.0
# 1      103.0
# 2      651.0
# 3      142.0
# 4      607.0

# %%
titanic.sort_values(by = "fare", ascending= False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck  \
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 88          1       1  female  23.0      3      2  263.0000        S    C
# 27          0       1    male  19.0      3      2  263.0000        S    C
# ..        ...     ...     ...   ...    ...    ...       ...      ...  ...
# 633         0       1    male   NaN      0      0    0.0000        S  NaN
# 413         0       2    male   NaN      0      0    0.0000        S  NaN
# 822         0       1    male  38.0      0      0    0.0000        S  NaN
# 732         0       2    male   NaN      0      0    0.0000        S  NaN
# 674         0       2    male   NaN      0      0    0.0000        S  NaN
#
#      fare_rank
# 258        1.0
# 737        1.0
# 679        1.0
# ...

# %% [markdown]
# # nunique(), nlargest() and nsmallest() with DataFrames

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic.nunique(axis = 0, dropna= False)
# Out:
# survived      2
# pclass        3
# sex           2
# age          89
# sibsp         7
# parch         7
# fare        248
# embarked      4
# deck          8
# dtype: int64

# %%
titanic.nlargest(n = 5, columns = "fare") #n is the number of rows ordered by the columns
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 27          0       1    male  19.0      3      2  263.0000        S    C
# 88          1       1  female  23.0      3      2  263.0000        S    C

# %%
titanic.sort_values("fare", ascending= False).head(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 737         1       1    male  35.0      0      0  512.3292        C    B
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 88          1       1  female  23.0      3      2  263.0000        S    C
# 27          0       1    male  19.0      3      2  263.0000        S    C

# %% [markdown]
# # Summary Statistics and Accumulations

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.count(axis = "columns") # count the number of non-missing value per row
# Out:
# 0      8
# 1      9
# 2      8
# 3      9
# 4      8
#       ..
# 886    8
# 887    9
# 888    7
# 889    9
# 890    8
# Length: 891, dtype: int64

# %%
titanic.sum(axis = 0, numeric_only=True)
# Out:
# survived      342.0000
# pclass       2057.0000
# age         21205.1700
# sibsp         466.0000
# parch         340.0000
# fare        28693.9493
# dtype: float64

# %%
titanic.sum(axis = 0, numeric_only=True).loc["survived"]
# Out:
# 342.0

# %%
titanic.corr(numeric_only=True)
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
titanic.survived.corr(titanic.pclass)
# Out:
# -0.3384810359610147

# %% [markdown]
# # The agg() method

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.select_dtypes("number").agg("mean")
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
titanic.select_dtypes("number").agg(["mean","std","min","max"])
# Out:
#       survived    pclass        age     sibsp     parch        fare
# mean  0.383838  2.308642  29.699118  0.523008  0.381594   32.204208
# std   0.486592  0.836071  14.526497  1.102743  0.806057   49.693429
# min   0.000000  1.000000   0.420000  0.000000  0.000000    0.000000
# max   1.000000  3.000000  80.000000  8.000000  6.000000  512.329200

# %%
titanic_summ = titanic.describe()

# %%
titanic_summ.iloc[1:4, :]
# Out:
#       survived    pclass        age     sibsp     parch       fare
# mean  0.383838  2.308642  29.699118  0.523008  0.381594  32.204208
# std   0.486592  0.836071  14.526497  1.102743  0.806057  49.693429
# min   0.000000  1.000000   0.420000  0.000000  0.000000   0.000000

# %% [markdown]
# # Apply(), map() and applymax()

# %%
import pandas as pd

# %%
sales = pd.read_csv("sales.csv", index_col=0)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Steven to Paul
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mon     4 non-null      int64
#  1   Tue     4 non-null      int64
#  2   Wed     4 non-null      int64
#  3   Thu     3 non-null      float64
#  4   Fri     4 non-null      int64
# dtypes: float64(1), int64(4)
# memory usage: 192.0+ bytes

# %%
sales.min(axis = 0) #get min for each column
# Out:
# Mon    17.0
# Tue     9.0
# Wed    15.0
# Thu     8.0
# Fri     7.0
# dtype: float64

# %%
sales.min(axis = 1) #get min for each row
# Out:
# Steven    15.0
# Mike       9.0
# Andi       8.0
# Paul       7.0
# dtype: float64

# %%
def range(series):
    return series.max() - series.min()

# %%
sales.apply(range, axis = 1)
# Out:
# Steven    19.0
# Mike      78.0
# Andi      46.0
# Paul      80.0
# dtype: float64

# %%
sales.apply(range, axis = 0)
# Out:
# Mon    70.0
# Tue    58.0
# Wed    59.0
# Thu    79.0
# Fri    26.0
# dtype: float64

# %%
sales.apply(lambda x: x.max() - x.min(), axis = 1)
# Out:
# Steven    19.0
# Mike      78.0
# Andi      46.0
# Paul      80.0
# dtype: float64

# %%
summer = pd.read_csv("summer.csv")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.Athlete.apply(lambda x: x[0])
# Out:
# 0        H
# 1        H
# 2        D
# 3        M
# 4        C
#         ..
# 31160    J
# 31161    R
# 31162    T
# 31163    A
# 31164    L
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.Athlete.map(lambda x: x[0])
# Out:
# 0        H
# 1        H
# 2        D
# 3        M
# 4        C
#         ..
# 31160    J
# 31161    R
# 31162    T
# 31163    A
# 31164    L
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.iloc[:,1:3]
# Out:
#          City      Sport
# 0      Athens   Aquatics
# 1      Athens   Aquatics
# 2      Athens   Aquatics
# 3      Athens   Aquatics
# 4      Athens   Aquatics
# ...       ...        ...
# 31160  London  Wrestling
# 31161  London  Wrestling
# 31162  London  Wrestling
# 31163  London  Wrestling
# 31164  London  Wrestling
#
# [31165 rows x 2 columns]

# %%
summer.iloc[:,1:3].applymap(lambda x: x[0])
# Out:
#       City Sport
# 0        A     A
# 1        A     A
# 2        A     A
# 3        A     A
# 4        A     A
# ...    ...   ...
# 31160    L     W
# 31161    L     W
# 31162    L     W
# 31163    L     W
# 31164    L     W
#
# [31165 rows x 2 columns]

# %% [markdown]
# # Hierarhcical Indexing (Multi - Index)

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic = titanic.iloc[:50, :]
titanic
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 0          0       3    male  22.0      1      0    7.2500        S  NaN
# 1          1       1  female  38.0      1      0   71.2833        C    C
# 2          1       3  female  26.0      0      0    7.9250        S  NaN
# 3          1       1  female  35.0      1      0   53.1000        S    C
# 4          0       3    male  35.0      0      0    8.0500        S  NaN
# 5          0       3    male   NaN      0      0    8.4583        Q  NaN
# 6          0       1    male  54.0      0      0   51.8625        S    E
# 7          0       3    male   2.0      3      1   21.0750        S  NaN
# 8          1       3  female  27.0      0      2   11.1333        S  NaN
# 9          1       2  female  14.0      1      0   30.0708        C  NaN
# 10         1       3  female   4.0      1      1   16.7000        S    G
# 11         1       1  female  58.0      0      0   26.5500        S    C
# ...

# %%
titanic.set_index(["pclass", "sex"], inplace=True)

# %%
titanic
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 3      male           0  22.0      1      0    7.2500        S  NaN
# 1      female         1  38.0      1      0   71.2833        C    C
# 3      female         1  26.0      0      0    7.9250        S  NaN
# 1      female         1  35.0      1      0   53.1000        S    C
# 3      male           0  35.0      0      0    8.0500        S  NaN
#        male           0   NaN      0      0    8.4583        Q  NaN
# 1      male           0  54.0      0      0   51.8625        S    E
# 3      male           0   2.0      3      1   21.0750        S  NaN
#        female         1  27.0      0      2   11.1333        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
# 3      female         1   4.0      1      1   16.7000        S    G
# 1      female         1  58.0      0      0   26.5500        S    C
# 3      male           0  20.0      0      0    8.0500        S  NaN
# ...

# %%
titanic.sort_index()
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        male           0  54.0      0      0   51.8625        S    E
#        male           1  28.0      0      0   35.5000        S    A
#        male           0  19.0      3      2  263.0000        S    C
#        male           0  40.0      0      0   27.7208        C  NaN
#        male           0  28.0      1      0   82.1708        C  NaN
#        male           0  42.0      1      0   52.0000        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
# ...

# %%
titanic.swaplevel()
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# sex    pclass
# male   3              0  22.0      1      0    7.2500        S  NaN
# female 1              1  38.0      1      0   71.2833        C    C
#        3              1  26.0      0      0    7.9250        S  NaN
#        1              1  35.0      1      0   53.1000        S    C
# male   3              0  35.0      0      0    8.0500        S  NaN
#        3              0   NaN      0      0    8.4583        Q  NaN
#        1              0  54.0      0      0   51.8625        S    E
#        3              0   2.0      3      1   21.0750        S  NaN
# female 3              1  27.0      0      2   11.1333        S  NaN
#        2              1  14.0      1      0   30.0708        C  NaN
#        3              1   4.0      1      1   16.7000        S    G
#        1              1  58.0      0      0   26.5500        S    C
# male   3              0  20.0      0      0    8.0500        S  NaN
# ...

# %%
titanic.reset_index(inplace= True)

# %%
titanic
# Out:
#     pclass     sex  survived   age  sibsp  parch      fare embarked deck
# 0        3    male         0  22.0      1      0    7.2500        S  NaN
# 1        1  female         1  38.0      1      0   71.2833        C    C
# 2        3  female         1  26.0      0      0    7.9250        S  NaN
# 3        1  female         1  35.0      1      0   53.1000        S    C
# 4        3    male         0  35.0      0      0    8.0500        S  NaN
# 5        3    male         0   NaN      0      0    8.4583        Q  NaN
# 6        1    male         0  54.0      0      0   51.8625        S    E
# 7        3    male         0   2.0      3      1   21.0750        S  NaN
# 8        3  female         1  27.0      0      2   11.1333        S  NaN
# 9        2  female         1  14.0      1      0   30.0708        C  NaN
# 10       3  female         1   4.0      1      1   16.7000        S    G
# 11       1  female         1  58.0      0      0   26.5500        S    C
# ...

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic = titanic.iloc[:50, :]

# %%
titanic = titanic.set_index(["pclass", 'sex']).sort_index(ascending= True)

# %%
titanic
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        male           0  54.0      0      0   51.8625        S    E
#        male           1  28.0      0      0   35.5000        S    A
#        male           0  19.0      3      2  263.0000        S    C
#        male           0  40.0      0      0   27.7208        C  NaN
#        male           0  28.0      1      0   82.1708        C  NaN
#        male           0  42.0      1      0   52.0000        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
# ...

# %%
titanic.loc[[1,2]]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
#        male           0  54.0      0      0   51.8625        S    E
#        male           1  28.0      0      0   35.5000        S    A
#        male           0  19.0      3      2  263.0000        S    C
#        male           0  40.0      0      0   27.7208        C  NaN
#        male           0  28.0      1      0   82.1708        C  NaN
#        male           0  42.0      1      0   52.0000        S  NaN
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
# ...

# %%
titanic.loc[1, "female"]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B

# %%
titanic.loc[(1, "female"), "age"]
# Out:
# pclass  sex
# 1       female    38.0
#         female    35.0
#         female    58.0
#         female     NaN
# Name: age, dtype: float64

# %%
titanic.loc[((1,2), "female"), ["age", "fare"]]
# Out:
#                 age      fare
# pclass sex
# 1      female  38.0   71.2833
#        female  35.0   53.1000
#        female  58.0   26.5500
#        female   NaN  146.5208
# 2      female  14.0   30.0708
#        female  55.0   16.0000
#        female  27.0   21.0000
#        female   3.0   41.5792

# %%
titanic.loc[(slice(None), slice("female")),:]
# Out:
#                survived   age  sibsp  parch      fare embarked deck
# pclass sex
# 1      female         1  38.0      1      0   71.2833        C    C
#        female         1  35.0      1      0   53.1000        S    C
#        female         1  58.0      0      0   26.5500        S    C
#        female         1   NaN      1      0  146.5208        C    B
# 2      female         1  14.0      1      0   30.0708        C  NaN
#        female         1  55.0      0      0   16.0000        S  NaN
#        female         0  27.0      1      0   21.0000        S  NaN
#        female         1   3.0      1      2   41.5792        C  NaN
# 3      female         1  26.0      0      0    7.9250        S  NaN
#        female         1  27.0      0      2   11.1333        S  NaN
#        female         1   4.0      1      1   16.7000        S    G
#        female         0  14.0      0      0    7.8542        S  NaN
#        female         0  31.0      1      0   18.0000        S  NaN
# ...

# %% [markdown]
# # String Operations

# %%
summer = pd.read_csv("summer.csv")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
names = summer.loc[:9, "Athlete"].copy()

# %%
names
# Out:
# 0            HAJOS, Alfred
# 1         HERSCHMANN, Otto
# 2        DRIVAS, Dimitrios
# 3       MALOKINIS, Ioannis
# 4       CHASAPIS, Spiridon
# 5    CHOROPHAS, Efstathios
# 6            HAJOS, Alfred
# 7         ANDREOU, Joannis
# 8    CHOROPHAS, Efstathios
# 9            NEUMANN, Paul
# Name: Athlete, dtype: object

# %%
names.dtypes
# Out:
# dtype('O')

# %%
names[0]
# Out:
# 'HAJOS, Alfred'

# %%
type(names[0])
# Out:
# str

# %%
names = names.str.lower()

# %%
names
# Out:
# 0            hajos, alfred
# 1         herschmann, otto
# 2        drivas, dimitrios
# 3       malokinis, ioannis
# 4       chasapis, spiridon
# 5    chorophas, efstathios
# 6            hajos, alfred
# 7         andreou, joannis
# 8    chorophas, efstathios
# 9            neumann, paul
# Name: Athlete, dtype: object

# %%
summer = pd.read_csv("summer.csv")

# %%
names = summer.loc[:9, "Athlete"].copy()
names
# Out:
# 0            HAJOS, Alfred
# 1         HERSCHMANN, Otto
# 2        DRIVAS, Dimitrios
# 3       MALOKINIS, Ioannis
# 4       CHASAPIS, Spiridon
# 5    CHOROPHAS, Efstathios
# 6            HAJOS, Alfred
# 7         ANDREOU, Joannis
# 8    CHOROPHAS, Efstathios
# 9            NEUMANN, Paul
# Name: Athlete, dtype: object

# %%
names.str.upper()
# Out:
# 0            HAJOS, ALFRED
# 1         HERSCHMANN, OTTO
# 2        DRIVAS, DIMITRIOS
# 3       MALOKINIS, IOANNIS
# 4       CHASAPIS, SPIRIDON
# 5    CHOROPHAS, EFSTATHIOS
# 6            HAJOS, ALFRED
# 7         ANDREOU, JOANNIS
# 8    CHOROPHAS, EFSTATHIOS
# 9            NEUMANN, PAUL
# Name: Athlete, dtype: object

# %%
names.str.title()
# Out:
# 0            Hajos, Alfred
# 1         Herschmann, Otto
# 2        Drivas, Dimitrios
# 3       Malokinis, Ioannis
# 4       Chasapis, Spiridon
# 5    Chorophas, Efstathios
# 6            Hajos, Alfred
# 7         Andreou, Joannis
# 8    Chorophas, Efstathios
# 9            Neumann, Paul
# Name: Athlete, dtype: object

# %%
summer.Event.str.split(" ", n = 2, expand= True)
# Out:
#           0          1            2
# 0      100M  Freestyle         None
# 1      100M  Freestyle         None
# 2      100M  Freestyle  For Sailors
# 3      100M  Freestyle  For Sailors
# 4      100M  Freestyle  For Sailors
# ...     ...        ...          ...
# 31160    Wg         84           KG
# 31161    Wg         96           KG
# 31162    Wg         96           KG
# 31163    Wg         96           KG
# 31164    Wg         96           KG
#
# [31165 rows x 3 columns]

# %%
summer.loc[summer.Event.str.contains("100M")]
# Out:
#        Year    City      Sport Discipline               Athlete Country  \
# 0      1896  Athens   Aquatics   Swimming         HAJOS, Alfred     HUN
# 1      1896  Athens   Aquatics   Swimming      HERSCHMANN, Otto     AUT
# 2      1896  Athens   Aquatics   Swimming     DRIVAS, Dimitrios     GRE
# 3      1896  Athens   Aquatics   Swimming    MALOKINIS, Ioannis     GRE
# 4      1896  Athens   Aquatics   Swimming    CHASAPIS, Spiridon     GRE
# ...     ...     ...        ...        ...                   ...     ...
# 29660  2012  London  Athletics  Athletics       STEWART, Kerron     JAM
# 29661  2012  London  Athletics  Athletics  BRYZGINA, Yelyzaveta     UKR
# 29662  2012  London  Athletics  Athletics          POVH, Olesya     UKR
# 29663  2012  London  Athletics  Athletics       RYEMYEN, Mariya     UKR
# 29664  2012  London  Athletics  Athletics        STUY, Hrystyna     UKR
#
#       Gender                       Event   Medal
# 0        Men              100M Freestyle    Gold
# ...
