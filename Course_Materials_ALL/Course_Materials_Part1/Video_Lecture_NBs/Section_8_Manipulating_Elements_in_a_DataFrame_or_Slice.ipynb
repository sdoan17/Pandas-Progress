# %% [markdown]
# # Manipulating Values in DataFrame

# %% [markdown]
# # Best Practise

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# # Changing a single Value (Option 1 with loc)

# %%
titanic.loc[1,"age"] = 40
# Out:
# 38.0

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  40.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# # Changing a single value (Option 2 with iloc)

# %%
titanic.iloc[1,3] = 38
# Out:
# 'female'

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# # Changing multiple values in a column (Option 1 with loc)

# %%
titanic.loc[1:3,'age'] = 42
# Out:
# 1    34.0
# 2    23.0
# 3    21.0
# Name: age, dtype: float64

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  42.0      1      0  71.2833        C    C
# 2         1       3  female  42.0      0      0   7.9250        S  NaN
# 3         1       1  female  42.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# # Changing multiple values in a column (Option 2 with iloc)

# %%
titanic.iloc[1:4,3] = [34,23,21]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  34.0      1      0  71.2833        C    C
# 2         1       3  female  23.0      0      0   7.9250        S  NaN
# 3         1       1  female  21.0      1      0  53.1000        S    C
# 4         0       3    male  42.0      0      0   8.0500        S  NaN

# %% [markdown]
# # Changing multiple values in a column (Option 3 with boolean indexing)

# %%
index_babi = titanic.loc[titanic.age<1,"age"].index

# %%
titanic.loc[titanic.age<1,"age"] = 1

# %%
titanic.loc[index_babi]
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.0      0      2   29.0000        S  NaN
# 305         1       1    male  1.0      1      2  151.5500        S    C
# 469         1       3  female  1.0      2      1   19.2583        C  NaN
# 644         1       3  female  1.0      2      1   19.2583        C  NaN
# 755         1       2    male  1.0      1      1   14.5000        S  NaN
# 803         1       3    male  1.0      0      1    8.5167        C  NaN
# 831         1       2    male  1.0      1      1   18.7500        S  NaN

# %% [markdown]
# # Changing multiple values in a row

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  34.0      1      0  71.2833        C    C
# 2         1       3  female  23.0      0      0   7.9250        S  NaN
# 3         1       1  female  21.0      1      0  53.1000        S    C
# 4         0       3    male  42.0      0      0   8.0500        S  NaN

# %%
titanic.loc[0,"survived":"sex"] = [1,1,"female"]

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         1       1  female  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  34.0      1      0  71.2833        C    C
# 2         1       3  female  23.0      0      0   7.9250        S  NaN
# 3         1       1  female  21.0      1      0  53.1000        S    C
# 4         0       3    male  42.0      0      0   8.0500        S  NaN

# %% [markdown]
# # Changing multiple values in multiple rows/columns

# %%
titanic.replace(0,"Zero")
# Out:
#     survived  pclass     sex   age sibsp parch     fare embarked deck
# 0          1       1  female  22.0     1  Zero     7.25        S  NaN
# 1          1       1  female  34.0     1  Zero  71.2833        C    C
# 2          1       3  female  23.0  Zero  Zero    7.925        S  NaN
# 3          1       1  female  21.0     1  Zero     53.1        S    C
# 4       Zero       3    male  42.0  Zero  Zero     8.05        S  NaN
# ..       ...     ...     ...   ...   ...   ...      ...      ...  ...
# 886     Zero       2    male  27.0  Zero  Zero     13.0        S  NaN
# 887        1       1  female  19.0  Zero  Zero     30.0        S    B
# 888     Zero       3  female   NaN     1     2    23.45        S  NaN
# 889        1       1    male  26.0  Zero  Zero     30.0        C    C
# 890     Zero       3    male  32.0  Zero  Zero     7.75        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.replace("Zero",0)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           1       1  female  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  34.0      1      0  71.2833        C    C
# 2           1       3  female  23.0      0      0   7.9250        S  NaN
# 3           1       1  female  21.0      1      0  53.1000        S    C
# 4           0       3    male  42.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# # How you should NOT do it (part 1)

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
age = titanic.age

# %%
age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
age[1] = 40
# Out:
# /var/folders/yj/fl4yb7h11bdb9093bzcwnr_w0000gn/T/ipykernel_32675/2108408145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age[1] = 40

# %%
age.head()
# Out:
# 0    22.0
# 1    40.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  40.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.age[1] = 41 #this is chained indexing!!!!
# Out:
# /var/folders/yj/fl4yb7h11bdb9093bzcwnr_w0000gn/T/ipykernel_32675/459450226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic.age[1] = 41 #this is chained indexing!!!!

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  41.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.loc[1,"age"] = 38 #best way

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# # View vs. Copy

# %% [markdown]
# # Slicing a DataFrame / creating a view on the original DataFrame

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
age = titanic.age #create the view, if you change the view, you'll change the original data frame

# %%
age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
age._is_view
# Out:
# True

# %%
age._is_copy is None
# Out:
# True

# %%
age[1] = 40
# Out:
# /var/folders/yj/fl4yb7h11bdb9093bzcwnr_w0000gn/T/ipykernel_32675/2108408145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age[1] = 40

# %%
age.head()
# Out:
# 0    22.0
# 1    40.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  40.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %% [markdown]
# # Slicing a DataFrame / creating a copy of the original DataFrame

# %%
df_baby = titanic[titanic.age < 1]

# %%
df_baby._is_view
# Out:
# False

# %%
df_baby._is_copy is None
# Out:
# False

# %%
df_baby._is_copy() #when you slice you create a copy
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  40.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df_baby.age = 1
# Out:
# /var/folders/yj/fl4yb7h11bdb9093bzcwnr_w0000gn/T/ipykernel_32675/4242927430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_baby.age = 1

# %%
titanic.loc[titanic.age < 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 78          1       2    male  0.83      0      2   29.0000        S  NaN
# 305         1       1    male  0.92      1      2  151.5500        S    C
# 469         1       3  female  0.75      2      1   19.2583        C  NaN
# 644         1       3  female  0.75      2      1   19.2583        C  NaN
# 755         1       2    male  0.67      1      1   14.5000        S  NaN
# 803         1       3    male  0.42      0      1    8.5167        C  NaN
# 831         1       2    male  0.83      1      1   18.7500        S  NaN

# %% [markdown]
# # If you want to work with and manipulate the whole DataFrame..

# %% [markdown]
# # .... avoid chained indexing!!!!

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.iloc[1,3] = 40

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  40.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
index_baby = titanic.loc[titanic.age < 1, "age"].index

# %%
titanic.loc[titanic.age < 1, "age"] = 1

# %%
titanic.loc[index_baby]
# Out:
#      survived  pclass     sex  age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.0      0      2   29.0000        S  NaN
# 305         1       1    male  1.0      1      2  151.5500        S    C
# 469         1       3  female  1.0      2      1   19.2583        C  NaN
# 644         1       3  female  1.0      2      1   19.2583        C  NaN
# 755         1       2    male  1.0      1      1   14.5000        S  NaN
# 803         1       3    male  1.0      0      1    8.5167        C  NaN
# 831         1       2    male  1.0      1      1   18.7500        S  NaN

# %% [markdown]
# # if you want to work with and manipulate a Slice of a DataFrame...

# %% [markdown]
# # ... and make a copy with .copy()

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
age = titanic.age.copy() #create a copy, so if you change it, it only affacts the copy

# %%
age[1] = 40

# %%
age.head()
# Out:
# 0    22.0
# 1    40.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
baby_age = titanic.loc[titanic.age < 1, ["age", "sex"]].copy()

# %%
baby_age
# Out:
#       age     sex
# 78   0.83    male
# 305  0.92    male
# 469  0.75  female
# 644  0.75  female
# 755  0.67    male
# 803  0.42    male
# 831  0.83    male

# %%
baby_age["age"] = 1

# %%
baby_age
# Out:
#      age     sex
# 78     1    male
# 305    1    male
# 469    1  female
# 644    1  female
# 755    1    male
# 803    1    male
# 831    1    male
