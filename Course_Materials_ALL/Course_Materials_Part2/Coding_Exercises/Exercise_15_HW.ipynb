# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv("cars.csv")

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0          1970     usa  chevrolet chevelle malibu
# 1          1970     usa          buick skylark 320
# 2          1970     usa         plymouth satellite
# 3          1970     usa              amc rebel sst
# 4          1970     usa                ford torino
# ..          ...     ...                        ...
# 393        1982     usa            ford mustang gl
# 394        1982  europe                  vw pickup
# 395        1982     usa              dodge rampage
# 396        1982     usa                ford ranger
# 397        1982     usa             chevrolet s-10
#
# [398 rows x 9 columns]

# %%
cars.model_year.value_counts()
# Out:
# model_year
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: count, dtype: int64

# %%
cars.model_year = cars.model_year.add(1900)

# %%
cars.plot(kind = "scatter", x = "horsepower", y = "mpg", figsize= (12, 8), fontsize= 13)
plt.show()

# %%
cars["gpm"] = (1/cars.mpg*100).round(2)

# %%
cars.plot(kind = "scatter", x = "horsepower", y = "gpm" , figsize= (12, 8), fontsize= 13)
plt.show()

# %%
cars["manufacturer"] = cars.name.str.split(" ", n = 1, expand = True)[0]

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name   gpm manufacturer
# 0          1970     usa  chevrolet chevelle malibu  5.56    chevrolet
# 1          1970     usa          buick skylark 320  6.67        buick
# 2          1970     usa         plymouth satellite  5.56     plymouth
# 3          1970     usa              amc rebel sst  6.25          amc
# 4          1970     usa                ford torino  5.88         ford
# ..          ...     ...                        ...   ...          ...
# 393        1982     usa            ford mustang gl  3.70         ford
# 394        1982  europe                  vw pickup  2.27           vw
# 395        1982     usa              dodge rampage  3.12        dodge
# 396        1982     usa                ford ranger  3.57         ford
# 397        1982     usa             chevrolet s-10  3.23    chevrolet
#
# [398 rows x 11 columns]
